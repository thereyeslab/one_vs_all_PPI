# %%
# !pip install --quiet git+https://github.com/jurgjn/pooled-ppi.git
#!pip install --quiet pooled-ppi
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 64.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !wget --quiet https://raw.githubusercontent.com/jurgjn/pooled-ppi/refs/heads/main/examples-colab/sample-pools-mgen/sequences.tsv
# !echo "sequences.tsv has input sequence identifiers and lengths separated by whitespace:"
# !head -n 20 sequences.tsv
# Out:
# sequences.tsv has input sequence identifiers and lengths separated by whitespace:
# aac71217.2	380
# aac71218.2	310
# aac71219.1	650
# aac71220.1	836
# aac71221.1	417
# aac71222.1	210
# aac71223.1	254
# aac71224.1	442
# aac71225.1	262
# aac71226.1	218
# aac71227.1	287
# aac71228.1	287
# aac71229.2	273
# aac71230.1	623
# aac71231.1	589
# aac71234.2	1031
# aac71235.1	389
# aac71236.1	308
# aac71237.1	512
# aac71238.1	145

# %%
# !echo "Sample all-vs-all pools between first 20 input sequences"
# !head -n 20 sequences.tsv | pooled-ppi-sample --max_pool_size=5000
# Out:
# Sample all-vs-all pools between first 20 input sequences
# 2 threads available for numba
# 20 proteins in input
# 100% 190/190 [00:02<00:00, 92.61it/s]
# 5 pools generated
# 190 interactions expected
# 190 interactions across all pools generated
# True pools include all possible interactions
# 1.510508704306149 length-weighted redundancy factor across all pools
# pool_id	pool_size
# aac71217.2_aac71218.2_aac71219.1_aac71220.1_aac71221.1_aac71222.1_aac71223.1_aac71224.1_aac71225.1_aac71226.1_aac71227.1_aac71231.1_aac71238.1	5000.0
# aac71217.2_aac71222.1_aac71223.1_aac71225.1_aac71226.1_aac71228.1_aac71229.2_aac71230.1_aac71234.2_aac71235.1_aac71236.1_aac71237.1_aac71238.1	4892.0
# aac71218.2_aac71221.1_aac71224.1_aac71227.1_aac71228.1_aac71229.2_aac71230.1_aac71231.1_aac71235.1_aac71236.1_aac71237.1	4437.0
# aac71218.2_aac71219.1_aac71220.1_aac71227.1_aac71228.1_aac71229.2_aac71234.2_aac71235.1_aac71236.1_aac71237.1	4883.0
# ...

# %%
# !echo "Sample all-vs-all pools proteome-wide (<2 min):"
# !cat sequences.tsv | pooled-ppi-sample --max_pool_size=5000 > sample-pools-mgen.tsv
# Out:
# Sample all-vs-all pools proteome-wide (<2 min):
# 2 threads available for numba
# 476 proteins in input
# 100% 113050/113050 [00:02<00:00, 39230.21it/s]
# 1865 pools generated
# 113050 interactions expected
# 113050 interactions across all pools generated
# True pools include all possible interactions
# 1.3318286112317754 length-weighted redundancy factor across all pools

# %%
# !echo "Number of pools slightly lower than originally (2,027) as sequence lengths included in optimisation:"
# !wc -l sample-pools-mgen.tsv
# !echo "Output has pool identifier (members separated by underscores) and pool size:"
# !head -n 5 sample-pools-mgen.tsv
# Out:
# Number of pools slightly lower than originally (2,027) as sequence lengths included in optimisation:
# 1866 sample-pools-mgen.tsv
# Output has pool identifier (members separated by underscores) and pool size:
# pool_id	pool_size
# aac71217.2_aac71218.2_aac71219.1_aac71220.1_aac71221.1_aac71222.1_aac71223.1_aac71224.1_aac71225.1_aac71226.1_aac71227.1_aac71228.1_aac71257.1_aac71564.1	4981.0
# aac71217.2_aac71229.2_aac71230.1_aac71231.1_aac71234.2_aac71235.1_aac71236.1_aac71237.1_aac71238.1_aac71239.1_aac71272.1_aac72463.1	4981.0
# aac71217.2_aac71240.1_aac71241.1_aac71242.1_aac71243.1_aac71244.1_aac71245.1_aac71246.1_aac71247.1_aac71248.1_aac71249.1_aac71250.1_aac71638.1_abc59632.1	4973.0
# aac71217.2_aac71251.1_aac71252.1_aac71253.1_aac71254.1_aac71255.1_aac71256.1_aac71258.1_aac71259.1_aac71260.1_aac71265.2_aac71461.2	4993.0
